# %% [markdown]
# <a href="https://colab.research.google.com/github/JJIMINSHIN/BIGDATA/blob/main/Kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sat Nov 13 01:52:20 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8    26W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount("./content/")
# Out:
# Drive already mounted at ./content/; to attempt to forcibly remount, call drive.mount("./content/", force_remount=True).

# %%
# %cd "/content/content/MyDrive/new/kaggle"
# Out:
# /content/content/MyDrive/new/kaggle

# %%
import pandas as pd
import numpy as np
import torch
import gc
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('/content/content/MyDrive/new/kaggle/train.csv').drop('id', axis=1)
test = pd.read_csv('/content/content/MyDrive/new/kaggle/test.csv').drop('id', axis=1)
ss = pd.read_csv('/content/content/MyDrive/new/kaggle/sample_submission.csv')

# %%
train.head(10)
# Out:
#          f0        f1         f2       f3  ...      f97       f98       f99  target
# 0  0.106643  3.594370  132.80400  3.18428  ...  1.97877  0.085974  0.240496       0
# 1  0.125021  1.673360   76.53360  3.37825  ...  2.57786 -0.020877  0.024719       0
# 2  0.036330  1.497470  233.54600  2.19435  ...  2.14112  0.124464  0.148209       0
# 3 -0.014077  0.246000  779.96700  1.89064  ...  1.96860  0.040017  0.044873       0
# 4 -0.003259  3.715420  156.12800  2.14772  ...  1.07481 -0.012819  0.072798       1
# 5  0.026798  0.801415  136.59800  2.35950  ...  1.30932  0.159111  0.111462       1
# 6  0.940176  4.301660  835.78500  4.65820  ...  3.72522  0.028623  0.450104       1
# 7  0.496696  3.502990    9.41337  2.30188  ...  5.27379  0.014103  1.671650       1
# 8 -0.007282  3.957490  124.70400  2.24207  ...  3.75430  0.097077  0.168881       0
# 9  0.398484  3.522350  -78.56650  4.62125  ...  4.51370 -0.007133  0.817078       0
#
# [10 rows x 101 columns]

# %%
x = train.drop('target', axis=1).copy()
y = train['target'].copy()
x_test = test.copy()

del train
gc.collect()
del test
gc.collect()
# Out:
# 0

# %%
scaler = StandardScaler()

x = pd.DataFrame(columns=x.columns, data=scaler.fit_transform(x))
x_test = pd.DataFrame(columns=x_test.columns, data=scaler.transform(x_test))

# %%
x.head()
# Out:
#          f0        f1        f2  ...       f97       f98       f99
# 0 -0.382553  0.705772 -0.315075  ... -0.400887 -0.167145  0.443374
# 1 -0.347377 -0.530387 -0.417061  ... -0.008064 -0.412110 -0.371198
# 2 -0.517136 -0.643571 -0.132486  ... -0.294434 -0.078904  0.094984
# 3 -0.613619 -1.448884  0.857867  ... -0.407556 -0.272505 -0.295118
# 4 -0.592913  0.783666 -0.272802  ... -0.993613 -0.393636 -0.189697
#
# [5 rows x 100 columns]

# %%
# %%time

EPOCHS = 100
KFold = StratifiedKFold(n_splits=5, random_state = 700, shuffle = True)

for fold, (train_idx, valid_idx) in enumerate(KFold.split(x, y)):
  x_train, x_valid = x.iloc[train_idx].values, x.iloc[valid_idx].values
  y_train, y_valid = y.iloc[train_idx].values, y.iloc[valid_idx].values

  x_train = torch.from_numpy(x_train.astype(np.float32))
  x_valid = torch.from_numpy(x_valid.astype(np.float32))
  y_train = torch.from_numpy(y_train.astype(np.float32).reshape(-1, 1))
  y_valid = torch.from_numpy(y_valid.astype(np.float32).reashape(-1, 1))

  model = nn.Sequential(
      nn.Linear(100, 1),
      nn.Sigmoid()
  ) 

  criterion = nn.BCELoss()
  optimizer = torch.optim.Adam(model.parameters(), lr = 0.01)

  train_losses = np.zeros(EPOCHS)
  valid_losses = np.zeros(EPOCHS)

  scores = np.zeros(EPOCHS)

  for ep in range(EPOCHS):
    optim
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-ba27aa9ef6dc> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', '\nEPOCHS = 100\nKFold = StratifiedKFold(n_splits=5, random_state = 700, shuffle = True)\n\nfor fold, (train_idx, valid_idx) in enumerate(KFold.split(x, y)):\n  x_train, x_valid = x.iloc[train_idx].values, x.iloc[valid_idx].values\n  y_train, y_valid = y.iloc[train_idx].values, y.iloc[valid_idx].values\n\n  x_train = torch.from_numpy(x_train.astype(np.float32))\n  x_valid = torch.from_numpy(x_valid.astype(np.float32))\n  y_train = torch.from_numpy(y_train.astype(np.float32).reshape(-1, 1))\n  y_valid = torch.from_numpy(y_valid.astype(np.float32).reashape(-1, 1))\n\n  model = nn.Sequential(\n      nn.Linear(100, 1),\n      nn.Sigmoid()\n  ) ')
#
# ...
